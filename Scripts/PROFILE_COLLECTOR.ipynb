# %%
# import pyautogui
# import random
# import time
# from selenium import webdriver
# from selenium.webdriver.chrome.service import Service
# from selenium.webdriver.chrome.options import Options
# from selenium.webdriver.common.by import By
# from selenium.webdriver.common.keys import Keys
# from webdriver_manager.chrome import ChromeDriverManager
# import pandas as pd

# # -------------------- STEP 1: Launch Chrome with Selenium -------------------- #
# options = Options()
# options.add_argument("--disable-blink-features=AutomationControlled")  # less detectable
# options.add_experimental_option("excludeSwitches", ["enable-automation"])
# options.add_experimental_option("useAutomationExtension", False)
# options.add_argument("start-maximized")

# # No profile used for anonymity

# driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
# driver.execute_cdp_cmd("Page.addScriptToEvaluateOnNewDocument", {
#     "source": "Object.defineProperty(navigator, 'webdriver', {get: () => undefined})"
# })

# # -------------------- STEP 2: Human-like Mouse Movement -------------------- #
# def move_mouse_like_human(times=10):
#     screen_width, screen_height = pyautogui.size()
#     for _ in range(times):
#         x = random.randint(100, screen_width - 100)
#         y = random.randint(100, screen_height - 100)
#         print(f"➡️ Moving mouse to ({x}, {y})")
#         pyautogui.moveTo(x, y, duration=random.uniform(0.5, 1.5))
#         time.sleep(random.uniform(0.5, 1.0))

# # -------------------- STEP 3: Open LinkedIn and Collect Profiles -------------------- #
# search_keywords = [
#     "hr it bangalore",
#     "talent acquisition delhi",
#     "technical recruiter pune"
# ]

# profile_data = []

# for keyword in search_keywords:
#     query = keyword.replace(" ", "%20")
#     url = f"https://www.linkedin.com/search/results/people/?keywords={query}"
#     driver.get(url)
#     time.sleep(5)
#     move_mouse_like_human(5)  # Simulate mouse movement after load

#     profiles = driver.find_elements(By.CLASS_NAME, "reusable-search__result-container")

#     for p in profiles:
#         try:
#             name = p.find_element(By.TAG_NAME, "span").text
#             link_elem = p.find_element(By.TAG_NAME, "a")
#             link = link_elem.get_attribute("href")
#             title = p.text
#             profile_data.append({
#                 "name": name,
#                 "link": link,
#                 "title_snippet": title
#             })
#         except Exception as e:
#             print(f"⚠️ Skipping a profile: {e}")
#             continue

# # -------------------- STEP 4: Save to CSV -------------------- #
# df = pd.DataFrame(profile_data)
# df.to_csv("linkedin_hr_profiles.csv", index=False)
# print("✅ Done! Profiles saved in CSV.")

# # -------------------- STEP 5: Quit -------------------- #
# time.sleep(3)
# driver.quit()
